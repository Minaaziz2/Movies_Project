# %% [markdown]
# # Movies Project

# %%
#importing packages
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# allowing bigger table to show in one view 
pd.options.display.max_columns = 30

# %%
# reading the csv file
df = pd.read_csv('movies_complete.csv', parse_dates=['release_date'])

# %%
#exploring the dataframe
df.head()
# Out:
#       id                        title  \
# 0    862                    Toy Story
# 1   8844                      Jumanji
# 2  15602             Grumpier Old Men
# 3  31357            Waiting to Exhale
# 4  11862  Father of the Bride Part II
#
#                                              tagline release_date  \
# 0                                                NaN   1995-10-30
# 1          Roll the dice and unleash the excitement!   1995-12-15
# 2  Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3  Friends are the people who let you be yourself...   1995-12-22
# 4  Just When His World Is Back To Normal... He's ...   1995-02-10
#
#                      genres           belongs_to_collection original_language  \
# 0   Animation|Comedy|Family            Toy Story Collection                en
# 1  Adventure|Fantasy|Family                             NaN                en
# 2            Romance|Comedy       Grumpy Old Men Collection                en
# ...

# %%
#exploring the data types and missing values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44691 entries, 0 to 44690
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     44691 non-null  int64
#  1   title                  44691 non-null  object
#  2   tagline                20284 non-null  object
#  3   release_date           44657 non-null  datetime64[ns]
#  4   genres                 42586 non-null  object
#  5   belongs_to_collection  4463 non-null   object
#  6   original_language      44681 non-null  object
#  7   budget_musd            8854 non-null   float64
#  8   revenue_musd           7385 non-null   float64
#  9   production_companies   33356 non-null  object
#  10  production_countries   38835 non-null  object
#  11  vote_count             44691 non-null  float64
#  12  vote_average           42077 non-null  float64
#  13  popularity             44691 non-null  float64
# ...

# %% [markdown]
# Describtive Analysis

# %%
df.describe()
# Out:
#                   id  budget_musd  revenue_musd    vote_count  vote_average  \
# count   44691.000000  8854.000000   7385.000000  44691.000000  42077.000000
# mean   107186.242845    21.669886     68.968649    111.653778      6.003341
# std    111806.362236    34.359837    146.608966    495.322313      1.281060
# min         2.000000     0.000001      0.000001      0.000000      0.000000
# 25%     26033.500000     2.000000      2.405420      3.000000      5.300000
# 50%     59110.000000     8.200000     16.872671     10.000000      6.100000
# 75%    154251.000000    25.000000     67.642693     35.000000      6.800000
# max    469172.000000   380.000000   2787.965087  14075.000000     10.000000
#
#          popularity       runtime     cast_size     crew_size
# count  44691.000000  43179.000000  44691.000000  44691.000000
# mean       2.957460     97.566850     12.479090     10.313643
# std        6.040008     34.653409     12.124663     15.892154
# ...

# %%
#fill the mising values in profits and votes by 0
df.budget_musd.fillna(0,inplace=True)
df.vote_count.fillna(0,inplace=True)

# %%
df.hist(figsize=(20,12), bins =100)
# Out:
# array([[<AxesSubplot:title={'center':'id'}>,
#         <AxesSubplot:title={'center':'release_date'}>,
#         <AxesSubplot:title={'center':'budget_musd'}>],
#        [<AxesSubplot:title={'center':'revenue_musd'}>,
#         <AxesSubplot:title={'center':'vote_count'}>,
#         <AxesSubplot:title={'center':'vote_average'}>],
#        [<AxesSubplot:title={'center':'popularity'}>,
#         <AxesSubplot:title={'center':'runtime'}>,
#         <AxesSubplot:title={'center':'cast_size'}>],
#        [<AxesSubplot:title={'center':'crew_size'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
#majority of the rating score is between 5 and 8 
df['vote_average'].hist(figsize=(10,6),bins=50)
# Out:
# <AxesSubplot:>

# %%
#majority of movies have low budget
df['budget_musd'].hist(figsize=(10,6),bins=50, range=[0, 150])
plt.xlabel('budget in millions')
# Out:
# Text(0.5, 0, 'budget in millions')

# %%
#relationship between budget amount and rating
sns.regplot(df['budget_musd'],df['vote_average'],scatter_kws={"color": "blue"}, line_kws={"color": "red"})
# Out:
# C:\Users\mina.aziz\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='budget_musd', ylabel='vote_average'>

# %%
#relationship between revnue amount and rating
sns.regplot(df['revenue_musd'],df['vote_average'],scatter_kws={"color": "blue"}, line_kws={"color": "red"})
# Out:
# C:\Users\mina.aziz\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='revenue_musd', ylabel='vote_average'>

# %%
#relationship between run time amount and rating
sns.regplot(df['runtime'],df['vote_average'],scatter_kws={"color": "blue"}, line_kws={"color": "red"})
# Out:
# C:\Users\mina.aziz\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='runtime', ylabel='vote_average'>

# %%
#relationship between run time amount and revenue
sns.regplot(df['runtime'],df['revenue_musd'],scatter_kws={"color": "blue"}, line_kws={"color": "red"})
# Out:
# C:\Users\mina.aziz\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='runtime', ylabel='revenue_musd'>

# %%
# adding profit column 
df['profit'] = df['revenue_musd'] - df['budget_musd']

# %%
# top profit generating movies
top5 = df[['title','profit']].sort_values('profit', ascending=False).head()
plt.figure(figsize=(10,6))
sns.barplot(x=top5['title'],y=top5['profit'])
# Out:
# <AxesSubplot:xlabel='title', ylabel='profit'>

# %%
from IPython.display import HTML

# %%
top5p = df[['title','profit','poster_path']].sort_values('profit', ascending=False).head()
HTML(top5p.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>title</th>
#       <th>profit</th>
#       <th>poster_path</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>14448</th>
#       <td>Avatar</td>
#       <td>2550.965087</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//btnl50ZDJDSCal2NLQIYWw0XxvH.jpg' style='height:100px;'></td>
#     </tr>
#     <tr>
#       <th>26265</th>
#       <td>Star Wars: The Force Awakens</td>
#       <td>1823.223624</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//9rd002JS49RwDW944fF1wjU8iTV.jpg' style='height:100px;'></td>
#     </tr>
#     <tr>
#       <th>1620</th>
#       <td>Titanic</td>
#       <td>1645.034188</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//9xjZS2rlVxm8SFx8kPC3aIGCOYQ.jpg' style='height:100px;'></td>
#     </tr>
#     <tr>
#       <th>24812</th>
#       <td>Jurassic World</td>
#       <td>1363.528810</td>
# ...

# %%
#top 5 unprofitable genres by count of movies
unprofitable = df[df['profit']<0][['title', 'genres']].groupby('genres').count().reset_index()
top5_unprofitable = unprofitable.sort_values('title', ascending=False).head()
plt.figure(figsize=(10,6))
sns.barplot(x=top5_unprofitable['genres'],y=top5_unprofitable['title'])
# Out:
# <AxesSubplot:xlabel='genres', ylabel='title'>

# %%
# movies with duplicate name 
df[df['title'].duplicated()==1]['title'].count()
# Out:
# 3086

# %%
#count of each genre
df2 = df.copy()
gen = ['Animation','Comedy','Family','Adventure','Fantasy','Romance','Comedy','Crime','Horror']
for i in gen:
    df2[i] = df.genres.str.contains(i)*1
df2 = df2[['Animation','Comedy','Family','Adventure','Fantasy','Romance','Comedy','Crime','Horror']]
df2 = df2.melt(var_name="Gen", value_name="Count")
df2 = df2.groupby('Gen').sum().reset_index()
plt.figure(figsize=(10,6))
sns.barplot(x=df2['Gen'],y=df2['Count'])
# Out:
# <AxesSubplot:xlabel='Gen', ylabel='Count'>

# %%
# most common used words in the moview titles
from wordcloud import WordCloud
title = df.title.dropna()
one_str = ' '.join(title)
title_wordcloud = WordCloud(background_color='white', height=2000,
                            width = 4000, max_words=100).generate(one_str)
plt.figure(figsize=(16,8))
plt.imshow(title_wordcloud, interpolation="bilinear")
plt.axis('off')
# Out:
# (-0.5, 3999.5, 1999.5, -0.5)

# %%
# being part of series definitely affects the movie profit as an average
df['part_of_series'] = np.where(df['belongs_to_collection'].notna(),'series','single')
df[['profit','part_of_series']].groupby('part_of_series').mean().reset_index()
# Out:
#   part_of_series      profit
# 0         series  127.022851
# 1         single   26.121400

# %%
# however, the voting doesn't look to have a big difference between single or series movies
df.groupby('part_of_series').agg(
    {'title':'count', 'budget_musd': ['sum','mean'],
     'revenue_musd':['sum','mean'], 'vote_average':'mean'})
# Out:
#                 title    budget_musd              revenue_musd              \
#                 count            sum       mean            sum        mean
# part_of_series
# series           4463   60621.998159  13.583240  245082.416858  165.708193
# single          40228  131243.173823   3.262483  264251.059520   44.742814
#
#                vote_average
#                        mean
# part_of_series
# series             5.956806
# single             6.008787

# %%
# most active directors
df['director'].value_counts().head(10)
# Out:
# John Ford           66
# Michael Curtiz      65
# Werner Herzog       54
# Alfred Hitchcock    53
# Georges Méliès      49
# Woody Allen         49
# Jean-Luc Godard     46
# Sidney Lumet        46
# Charlie Chaplin     44
# Raoul Walsh         43
# Name: director, dtype: int64

# %%
# most generating profits directors
direc = df[['profit','director']].groupby('director').sum().sort_values('profit',ascending=False).head(10).reset_index()
plt.figure(figsize=(20,6))
sns.barplot(x=direc['director'],y=direc['profit'])
# Out:
# <AxesSubplot:xlabel='director', ylabel='profit'>

# %%
# move id column to be the index 
df.set_index('id', inplace=True)

# %%
#seperate the actors of each movie to many columns 
act = df.cast.str.split('|',expand=True)

# %%
act = act.stack().reset_index(level=1,drop=True).to_frame()
act.columns=['Actor']

# %%
act.head()
# Out:
#              Actor
# id
# 862      Tom Hanks
# 862      Tim Allen
# 862    Don Rickles
# 862     Jim Varney
# 862  Wallace Shawn

# %%
act = act.merge(df[['title', 'revenue_musd','vote_average','popularity']],
               how = 'left',left_index=True,right_index=True)

# %%
# top 10 actors with the highest number of movies
act['Actor'].value_counts().head(10)
# Out:
# Bess Flowers         240
# Christopher Lee      148
# John Wayne           125
# Samuel L. Jackson    122
# Michael Caine        110
# Gérard Depardieu     109
# John Carradine       109
# Jackie Chan          108
# Donald Sutherland    108
# Frank Welker         107
# Name: Actor, dtype: int64
